# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gr_colo_spr = pd.read_csv("../data/groundwater_data/USGS_ColoradoSprings/WATERLEVEL.csv")
gr_colo_spr
# Out:
#      AgencyCd           SiteNo                       Time  Original Parameter  \
# 0        USGS  385607104230801  2002-02-08T12:00:00-00:00                 NaN
# 1        USGS  385607104230801  2002-04-11T12:00:00-00:00                 NaN
# 2        USGS  385607104230801  2002-06-06T12:00:00-00:00                 NaN
# 3        USGS  385607104230801  2002-11-21T12:00:00-00:00                 NaN
# 4        USGS  385607104230801  2003-02-27T12:00:00-00:00                 NaN
# ...       ...              ...                        ...                 ...
# 3047     USGS  384348104232901  2023-02-24T00:00:00-00:00                 NaN
# 3048     USGS  384348104232901  2023-02-25T00:00:00-00:00                 NaN
# 3049     USGS  384348104232901  2023-02-26T00:00:00-00:00                 NaN
# 3050     USGS  384348104232901  2023-02-27T00:00:00-00:00                 NaN
# 3051     USGS  384348104232901  2023-02-28T15:18:00-00:00                 NaN
#
#       Original Direction Original Unit  Original Value Accuracy Unit  \
# 0                    NaN            ft           85.72            ft
# 1                    NaN            ft           72.90            ft
# 2                    NaN            ft           76.23            ft
# 3                    NaN            ft           75.79            ft
# 4                    NaN            ft           72.42            ft
# ...                  ...           ...             ...           ...
# 3047                 NaN            ft         5642.15            ft
# 3048                 NaN            ft         5642.22            ft
# 3049                 NaN            ft         5642.30            ft
# 3050                 NaN            ft         5642.31            ft
# 3051                 NaN            ft         5642.37            ft
#
#      Accuracy Value  Depth to Water Below Land Surface in ft.  \
# 0           Unknown                                     85.72
# 1           Unknown                                     72.90
# 2           Unknown                                     76.23
# 3           Unknown                                     75.79
# 4           Unknown                                     72.42
# ...             ...                                       ...
# 3047        Unknown                                   5642.15
# 3048        Unknown                                   5642.22
# 3049        Unknown                                   5642.30
# 3050        Unknown                                   5642.31
# 3051        Unknown                                   5642.37
#
#       Water level in feet relative to NGVD29  Comment  Observation Method  \
# 0                                     6196.8      NaN                 NaN
# 1                                     6209.6      NaN                 NaN
# 2                                     6206.3      NaN                 NaN
# 3                                     6206.7      NaN                 NaN
# 4                                     6210.1      NaN                 NaN
# ...                                      ...      ...                 ...
# 3047                                    37.7      NaN                 NaN
# 3048                                    37.6      NaN                 NaN
# 3049                                    37.5      NaN                 NaN
# 3050                                    37.5      NaN                 NaN
# 3051                                    37.4      NaN                 NaN
#
#       Data Provided by  Unnamed: 14
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
# ...                ...          ...
# 3047               NaN          NaN
# 3048               NaN          NaN
# 3049               NaN          NaN
# 3050               NaN          NaN
# 3051               NaN          NaN
#
# [3052 rows x 15 columns]

# %%
gr_colo_spr_sites = gr_colo_spr['SiteNo'].unique()
gr_colo_spr_sites
# Out:
# array([385607104230801, 385344104242401, 390010104385101, 390148104285401,
#        385208104324401, 384824104332601, 384506104241302, 384348104232201,
#        384348104232901], dtype=int64)

# %%
# make dataframe for each site

gr_colo_spr_3856 = gr_colo_spr.loc[gr_colo_spr["SiteNo"] == 385607104230801]

gr_385344104242401 = gr_colo_spr.loc[gr_colo_spr["SiteNo"] == 385344104242401]

gr_384506104241302 = gr_colo_spr.loc[gr_colo_spr["SiteNo"] == 384506104241302]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    nrows = 3,
    ncols = 1,
    figsize = (15,10),
)

fig.suptitle("Groundwater Levels in Colorado Springs Area 2002-2023", fontsize = 30, y= 1)

ax1.plot(gr_colo_spr_3856["Time"], - gr_colo_spr_3856["Original Value"], linewidth = 5)
ax1.set_xticks(ticks = gr_colo_spr_3856["Time"][::12], labels = gr_colo_spr_3856["Time"][::12], rotation = 20)
ax1.set_title("Site 385607104230801")
#ax1.set_xlabel("Time")
ax1.set_ylabel("Water Level")

ax2.plot(gr_385344104242401["Time"], - gr_385344104242401["Original Value"], linewidth = 5)
ax2.set_xticks(gr_385344104242401["Time"][::12], gr_385344104242401["Time"][::12], rotation = 20)
ax2.set_title("Site 385344104242401")
#ax2.set_xlabel("Time")
ax2.set_ylabel("Water Level")

ax3.plot(gr_384506104241302["Time"], - gr_384506104241302['Original Value'], linewidth = 5)
ax3.set_xticks(gr_384506104241302['Time'][::12], gr_384506104241302["Time"][::12], rotation = 20)
ax3.set_title("Site 384506104241302")
ax3.set_ylabel("Water Level (Ft)")
ax3.set_xlabel("Time (DateTime")

fig.tight_layout()
fig.subplots_adjust(hspace=0.8)

plt.savefig("../Colorado_Springs_GWL_2002-2023")
